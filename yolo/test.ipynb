# %%
from ultralytics import YOLO

# Load your trained weights
model = YOLO("best.pt")

# Run on webcam
model.predict(source=0, show=True, conf=0.5)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 192x224 (no detections), 512.0ms
# 0: 192x224 (no detections), 48.5ms
# 0: 192x224 (no detections), 40.1ms
# 0: 192x224 (no detections), 40.7ms
# 0: 192x224 (no detections), 20.6ms
# 0: 192x224 (no detections), 17.0ms
# WARNING Waiting for stream 0
# 0: 192x224 (no detections), 21.0ms
# 0: 192x224 (no detections), 13.6ms
# 0: 192x224 (no detections), 16.2ms
# ...
